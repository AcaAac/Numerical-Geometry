# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import Delaunay

# %%
nodeData = [
    [ 0.16370661204827031, 0.4886650857430957],
    [ 0.83534964916824084, 0.4902996892628636],
    [ 0.49391845158624981, 0.1323760430705655],
    [ 0.49836539647917322, 0.82773865802723501 ],
    [ 0.30074819035913852, 0.83070291234383831],
    [ 0.39615987727709562, 0.67073444684008199],
    [ 0.6002015905170176, 0.67551889168744117],
    [ 0.50000000000250922, 0.48038475773043671 ],
    [ 0.83057691269884504, 0.30018449338884379],
    [ 0.81469961246449951, 0.68914937826112133],
    [ 0.16938214347656569, 0.30011357660650623 ],
    [ 0.18818969570926641, 0.68364148842842287 ],
    [ 0.31578456131778371, 0.1865278143482666 ],
    [ 0.69447607299129699, 0.84099946107689361 ],
    [ 0.68592116352011878, 0.1724872797865501],
    [ 0.32146143392436449, 0.38738071487621961 ],
    [ 0.66852282575985944, 0.3853248791658106],
    [ 0.47688326899416439, 0.31741132792405607 ],
    [ 0.14641016151479661, 0.85358983848542624 ],
    [ 0.85358983848570524, 0.85358983848556425 ],
    [ 0.1464101615145241, 0.14641016151486561],
    [ 0.85358983848650494, 0.1464101615132356 ],
    [ 0.31030302876556398, 0.54179813558513157 ],
    [ 0.68969697123394857, 0.54179813558228873]
]

# %%
# Compute Delaunay triangulation

nodeData = np.array(nodeData)
tri = Delaunay(nodeData)

# Plotting
plt.triplot(nodeData[:, 0], nodeData[:, 1], tri.simplices)
plt.scatter(nodeData[:, 0], nodeData[:, 1], color='red')  # plot the points
plt.show()
